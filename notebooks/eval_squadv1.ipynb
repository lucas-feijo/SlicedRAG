# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/TUM/Pratikum/lm-evaluation-harnessSquadV1.1
# Out:
# /content/drive/MyDrive/TUM/Pratikum/lm-evaluation-harnessSquadV1.1

# %%
# !pip install transformers evaluate datasets
# !pip install accelerate sentencepiece
# !pip install lm-evaluation-harness

# %%
# !pip install "lm-evaluation-harness[math,ifeval,sentencepiece]"
# !pip install transformers accelerate datasets evaluate sentencepiece sacrebleu

# %%
# !mkdir -p /content/custom_tasks/squad_v1
# !cp /content/drive/MyDrive/TUM/Pratikum/lm-evaluation-harnessSquadV1.1/custom_tasks/squad_v1/* /content/custom_tasks/squad_v1/
# Out:
# cp: -r not specified; omitting directory '/content/drive/MyDrive/TUM/Pratikum/lm-evaluation-harnessSquadV1.1/custom_tasks/squad_v1/__pycache__'

# %%
from lm_eval.tasks import TaskManager
tm = TaskManager(include_path="/content/custom_tasks",
                 include_defaults = False)
print(list(tm.all_tasks)[:20])  # should list squadv1
# Out:
# ['squadv1']

# %%
# !pip install -e ".[dev]"

# %%
# !rm -r /content/custom_tasks/

# %%
import os

BASE_RESULTS_DIR = "/content/drive/MyDrive/TUM/Pratikum/SliceGPTExperiments"
LOG_DIR = os.path.join(BASE_RESULTS_DIR, "logs")
MODEL_DIR = os.path.join(BASE_RESULTS_DIR, "models")
BASE_EVAL_DIR = os.path.join(BASE_RESULTS_DIR, "eval")

os.makedirs(LOG_DIR, exist_ok=True)
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(BASE_EVAL_DIR, exist_ok=True)

# %%
import logging
import sys

# Get the root logger or a named logger
logger = logging.getLogger()
logger.setLevel(logging.INFO)  # allow INFO and above

for h in list(logger.handlers):
  logger.removeHandler(h)

# Create a handler that writes to stdout
handler = logging.StreamHandler(sys.stdout)
handler.setLevel(logging.INFO)

# (Optional) set a formatting for readability
formatter = logging.Formatter('%(levelname)s - %(message)s')
handler.setFormatter(formatter)

# Add handler to the logger
logger.addHandler(handler)

# Now test
logger.info("This will be printed to stdout")
logger.debug("This will not print (level is INFO)")
# Out:
# INFO - This will be printed to stdout

# %%
import lm_eval
from lm_eval.tasks import TaskManager

# if your squadv1.yaml is inside the installed lm_eval/tasks tree,
# you don't need include_path
tm = TaskManager()

print("squadv1" in tm.all_tasks)      # or whatever name you put in `task:` in the yaml
# Out:
# True

# %%
import lm_eval
from lm_eval.models.huggingface import HFLM
from lm_eval.tasks import TaskManager

tm = TaskManager(
    include_path="/content/drive/MyDrive/TUM/Praktikum/lm-evaluation-harnessSquadV1.1/lm_eval/tasks/squad_v1"
)

model = HFLM(pretrained="facebook/opt-125m")

results = lm_eval.simple_evaluate(
    model,
    tasks=["squadv1"],   # this is the `task:` name in your YAML
    num_fewshot=0,
    batch_size=64,
    task_manager=tm,     # optional if your task is inside the installed lm_eval tree
)

print(results["results"])
# Out:
# INFO - NumExpr defaulting to 12 threads.
# INFO - TensorFlow version 2.19.0 available.
# INFO - JAX version 0.7.2 available.

# %%
import squad_v1.task
importlib.reload(squad_v1.task)

# %%
# !pip install sqlitedict
# Out:
# Collecting sqlitedict
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sqlitedict
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16862 sha256=07ee593796180c66bdd1b8d6a6f60a6e9cb1ffa9fc30e7301a19db58c208816f
#   Stored in directory: /root/.cache/pip/wheels/7a/6f/21/fc016aef45ffcabe27129a2252f061387cbf278d2086225a64
# Successfully built sqlitedict
# Installing collected packages: sqlitedict
# Successfully installed sqlitedict-2.1.0

# %%
#USE THIS ONE THIS TIME, it should work!!!
import os
import json
import logging
import torch
import lm_eval
from lm_eval.models.huggingface import HFLM
from lm_eval.tasks import TaskManager

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s - %(levelname)s - %(message)s"
)
logger = logging.getLogger(__name__)

logger.info("Starting SQuADv1 evaluation script")

# 1. Load custom task from LOCAL disk (not Drive)
TASK_PATH = "/content/custom_tasks/squad_v1"
logger.info(f"Initializing TaskManager with include_path={TASK_PATH}")
tm = TaskManager(include_path=TASK_PATH, include_defaults = False)

task_names = ["squadv1"]
#logger.info(f"Registered tasks: {list(tm.all_tasks.keys())}")
logger.info(f"Will evaluate on tasks: {task_names}")

# 2. Load model on GPU
MODEL_NAME = "facebook/opt-125m"
logger.info(f"Loading model: {MODEL_NAME}")

model = HFLM(pretrained=MODEL_NAME, device="cuda")

print("CUDA available:", torch.cuda.is_available())
print("Model device:", next(model.model.parameters()).device)

logger.info("Model loaded successfully")

# 3. Run evaluation
logger.info("Running lm_eval.simple_evaluate...")

results = lm_eval.simple_evaluate(
    model,
    tasks=task_names,
    num_fewshot=0,
    batch_size=64,
    task_manager=tm,
    limit=100,
    gen_kwargs={
        "until": ["<<END>>"],
        "max_gen_toks": 32,
        "temperature": 0.0,
        "do_sample": False,
    },
    use_cache=None,
    cache_requests=False,
    rewrite_requests_cache=False,
    delete_requests_cache=False,
    log_samples=False,
    write_out=False,
)






logger.info("Evaluation completed successfully")
logger.info(f"Metrics summary: {results['results']}")

# 4. Save results back to Drive
SAVE_DIR = "/content/drive/MyDrive/TUM/Pratikum/SliceGPTExperiments/eval/squad_dense_only/"
os.makedirs(SAVE_DIR, exist_ok=True)

sparsity_tag = "0.00"
filename = f"results_s{sparsity_tag}_{'_'.join(task_names)}_squadv1.json"
result_path = os.path.join(SAVE_DIR, filename)

metrics_only = results["results"]

with open(result_path, "w") as f:
    json.dump(metrics_only, f, indent=2)

logger.info(f"Saved results to: {result_path}")
logger.info("Finished SQuADv1 evaluation script")
# Out:
# INFO - Starting SQuADv1 evaluation script
# INFO - Initializing TaskManager with include_path=/content/custom_tasks/squad_v1
# INFO - Will evaluate on tasks: ['squadv1']
# INFO - Loading model: facebook/opt-125m
# INFO - Using device 'cuda'
# INFO - Model parallel was set to False, max memory was not set, and device map was set to {'': 'cuda'}
# CUDA available: True
# Model device: cuda:0
# INFO - Model loaded successfully
# INFO - Running lm_eval.simple_evaluate...
# INFO - Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# WARNING - generation_kwargs: {'until': ['<<END>>'], 'max_gen_toks': 32, 'temperature': 0.0, 'do_sample': False} specified through cli, these settings will update set parameters in yaml tasks. Ensure 'do_sample=True' for non-greedy decoding!
# INFO - Using pre-initialized model
# WARNING - squadv1: No `generation_kwargs` specified in task config, defaulting to {'until': ['\n\n'], 'do_sample': False, 'temperature': 0}
# INFO - Selected tasks:
# INFO - Task: squadv1 (/content/custom_tasks/squad_v1/squadv1.yaml)
# INFO - squadv1: Using gen_kwargs: {'until': ['<<END>>'], 'do_sample': False, 'temperature': 0.0, 'max_gen_toks': 32}
# WARNING - Overwriting default num_fewshot of squadv1 from None to 0
# INFO - Building contexts for squadv1 on rank 0...
# 100%|██████████| 100/100 [00:00<00:00, 3929.94it/s]
# INFO - Running generate_until requests
# Running generate_until requests: 100%|██████████| 100/100 [03:40<00:00,  2.20s/it]
# ==== RAW RESULTS ====
# types: []
# repr : []
# ==== DEBUG EXAMPLE ====
# ID      : 56be4db0acb8001400a502ec
# Q       : Which NFL team represented the AFC at Super Bowl 50?
# GT      : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED    : ''
# ==== RAW RESULTS ====
# types: []
# repr : []
# ==== DEBUG EXAMPLE ====
# ID      : 56be4db0acb8001400a502ed
# Q       : Which NFL team represented the NFC at Super Bowl 50?
# GT      : ['Carolina Panthers', 'Carolina Panthers', 'Carolina Panthers']
# PRED    : ''
# ==== RAW RESULTS ====
# types: []
# repr : []
# ==== DEBUG EXAMPLE ====
# ID      : 56be4db0acb8001400a502ee
# Q       : Where did Super Bowl 50 take place?
# GT      : ['Santa Clara, California', "Levi's Stadium", "Levi's Stadium in the San Francisco Bay Area at Santa Clara, California."]
# PRED    : ''
# ==== RAW RESULTS ====
# types: []
# repr : []
# ==== DEBUG EXAMPLE ====
# ID      : 56be4db0acb8001400a502ef
# Q       : Which NFL team won Super Bowl 50?
# GT      : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED    : ''
# ==== RAW RESULTS ====
# types: []
# repr : []
# ==== DEBUG EXAMPLE ====
# ID      : 56be4db0acb8001400a502f0
# Q       : What color was used to emphasize the 50th anniversary of the Super Bowl?
# GT      : ['gold', 'gold', 'gold']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be8e613aeaaa14008c90d1
# Q       : What was the theme of Super Bowl 50?
# GT      : ['"golden anniversary"', 'gold-themed', '"golden anniversary']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be8e613aeaaa14008c90d2
# Q       : What day was the game played on?
# GT      : ['February 7, 2016', 'February 7', 'February 7, 2016']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be8e613aeaaa14008c90d3
# Q       : What is the AFC short for?
# GT      : ['American Football Conference', 'American Football Conference', 'American Football Conference']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bea9923aeaaa14008c91b9
# Q       : What was the theme of Super Bowl 50?
# GT      : ['"golden anniversary"', 'gold-themed', 'gold']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bea9923aeaaa14008c91ba
# Q       : What does AFC stand for?
# GT      : ['American Football Conference', 'American Football Conference', 'American Football Conference']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bea9923aeaaa14008c91bb
# Q       : What day was the Super Bowl played on?
# GT      : ['February 7, 2016', 'February 7', 'February 7, 2016']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beace93aeaaa14008c91df
# Q       : Who won Super Bowl 50?
# GT      : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beace93aeaaa14008c91e0
# Q       : What venue did Super Bowl 50 take place in?
# GT      : ["Levi's Stadium", "Levi's Stadium", "Levi's Stadium in the San Francisco Bay Area at Santa Clara"]
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beace93aeaaa14008c91e1
# Q       : What city did Super Bowl 50 take place in?
# GT      : ['Santa Clara', 'Santa Clara', 'Santa Clara']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beace93aeaaa14008c91e2
# Q       : If Roman numerals were used, what would Super Bowl 50 have been called?
# GT      : ['Super Bowl L', 'L', 'Super Bowl L']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beace93aeaaa14008c91e3
# Q       : Super Bowl 50 decided the NFL champion for what season?
# GT      : ['2015', 'the 2015 season', '2015']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf10f43aeaaa14008c94fd
# Q       : What year did the Denver Broncos secure a Super Bowl title for the third time?
# GT      : ['2015', '2016', '2015']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf10f43aeaaa14008c94fe
# Q       : What city did Super Bowl 50 take place in?
# GT      : ['Santa Clara', 'Santa Clara', 'Santa Clara']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf10f43aeaaa14008c94ff
# Q       : What stadium did Super Bowl 50 take place in?
# GT      : ["Levi's Stadium", "Levi's Stadium", "Levi's Stadium"]
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf10f43aeaaa14008c9500
# Q       : What was the final score of Super Bowl 50?
# GT      : ['24–10', '24–10', '24–10']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf10f43aeaaa14008c9501
# Q       : What month, day and year did Super Bowl 50 take place?
# GT      : ['February 7, 2016', 'February 7, 2016', 'February 7, 2016']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d20362e7d4791d009025e8
# Q       : What year was Super Bowl 50?
# GT      : ['2015', '2016', '2016']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d20362e7d4791d009025e9
# Q       : What team was the AFC champion?
# GT      : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d20362e7d4791d009025ea
# Q       : What team was the NFC champion?
# GT      : ['Carolina Panthers', 'Carolina Panthers', 'Carolina Panthers']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d20362e7d4791d009025eb
# Q       : Who won Super Bowl 50?
# GT      : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d600e31c85041400946eae
# Q       : Super Bowl 50 determined the NFL champion for what season?
# GT      : ['2015', 'the 2015 season', '2015']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d600e31c85041400946eb0
# Q       : Which team won Super Bowl 50.
# GT      : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d600e31c85041400946eb1
# Q       : Where was Super Bowl 50 held?
# GT      : ['Santa Clara, California.', "Levi's Stadium", "Levi's Stadium"]
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d9895ddc89441400fdb50e
# Q       : The name of the NFL championship game is?
# GT      : ['Super Bowl', 'Super Bowl', 'Super Bowl']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d9895ddc89441400fdb510
# Q       : What 2015 NFL team one the AFC playoff?
# GT      : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be4e1facb8001400a502f6
# Q       : Which Carolina Panthers player was named Most Valuable Player?
# GT      : ['Cam Newton', 'Cam Newton', 'Cam Newton']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be4e1facb8001400a502f9
# Q       : How many appearances have the Denver Broncos made in the Super Bowl?
# GT      : ['8', 'eight', 'eight']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be4e1facb8001400a502fa
# Q       : What year was the Carolina Panthers franchise founded?
# GT      : ['1995', '1995', '1995']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beaa4a3aeaaa14008c91c2
# Q       : What team did the Panthers defeat?
# GT      : ['Arizona Cardinals', 'the Arizona Cardinals', 'Arizona Cardinals']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beaa4a3aeaaa14008c91c3
# Q       : Who did the Broncos prevent from going to the Super Bowl?
# GT      : ['New England Patriots', 'the New England Patriots', 'New England Patriots']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bead5a3aeaaa14008c91e9
# Q       : Who did the Panthers beat in the NFC Championship Game?
# GT      : ['Arizona Cardinals', 'the Arizona Cardinals', 'Arizona Cardinals']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bead5a3aeaaa14008c91ea
# Q       : Who lost to the Broncos in the AFC Championship?
# GT      : ['New England Patriots', 'the New England Patriots', 'New England Patriots']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bead5a3aeaaa14008c91eb
# Q       : Who were the defending Super Bowl champions?
# GT      : ['New England Patriots', 'the New England Patriots', 'New England Patriots']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bead5a3aeaaa14008c91ec
# Q       : How many teams have been in the Super Bowl eight times?
# GT      : ['four', 'four', 'four']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bead5a3aeaaa14008c91ed
# Q       : Who was this season's NFL MVP?
# GT      : ['Cam Newton', 'Cam Newton', 'Cam Newton']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf159b3aeaaa14008c9507
# Q       : What was the win/loss ratio in 2015 for the Carolina Panthers during their regular season?
# GT      : ['15–1', '15–1', '15–1']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf159b3aeaaa14008c9508
# Q       : Which Carolina Panthers team member was picked as the team's MVP in 2015?
# GT      : ['Cam Newton', 'Cam Newton', 'Cam Newton']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf159b3aeaaa14008c9509
# Q       : What were the win/loss game stats for the Denver Bronco's regular season in 2015?
# GT      : ['12–4', '12–4', '12–4']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf159b3aeaaa14008c950a
# Q       : How many teams have played in the Super Bowl eight times?
# GT      : ['4', 'four', 'four']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf159b3aeaaa14008c950b
# Q       : Which team did not get a chance to defend their Super Bowl XLIX win in Super Bowl 50?
# GT      : ['New England Patriots', 'the New England Patriots', 'New England Patriots']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d2045de7d4791d009025f3
# Q       : Who is the quarterback for the Panthers?
# GT      : ['Cam Newton', 'Cam Newton', 'Cam Newton']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d2045de7d4791d009025f4
# Q       : Who did Carolina beat in the NFC championship game?
# GT      : ['Arizona Cardinals', 'the Arizona Cardinals', 'Arizona Cardinals']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d2045de7d4791d009025f5
# Q       : How many times have the Panthers been in the Super Bowl?
# GT      : ['2', 'second', 'second']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d2045de7d4791d009025f6
# Q       : Who did Denver beat in the AFC championship?
# GT      : ['New England Patriots', 'the New England Patriots', 'New England Patriots']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d6017d1c85041400946ebe
# Q       : Who was the Most Valuable Player for the 2015 NFL season?
# GT      : ['Cam Newton', 'Cam Newton', 'Cam Newton']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d6017d1c85041400946ec1
# Q       : Who did Denver beat in the 2015 AFC Championship game?
# GT      : ['New England Patriots', 'the New England Patriots', 'New England Patriots']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d6017d1c85041400946ec2
# Q       : Who did the Carolina Panthers beat in the 2015 NFC Championship game?
# GT      : ['Arizona Cardinals', 'the Arizona Cardinals', 'Arizona Cardinals']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d98a59dc89441400fdb52a
# Q       : Who was the 2015 NFL MVP?
# GT      : ['Cam Newton', 'Cam Newton', 'Cam Newton']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d98a59dc89441400fdb52b
# Q       : Who did the Panthers beat to become the NFC champs?
# GT      : ['Arizona Cardinals', 'the Arizona Cardinals', 'Arizona Cardinals']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d98a59dc89441400fdb52e
# Q       : What year did the Carolina Panthers form?
# GT      : ['1995.', '1995', '1995']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be4eafacb8001400a50302
# Q       : Who was the Super Bowl 50 MVP?
# GT      : ['Von Miller', 'Von Miller', 'Miller']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be4eafacb8001400a50303
# Q       : How many fumbles did Von Miller force in Super Bowl 50?
# GT      : ['2', 'two', 'two']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be4eafacb8001400a50304
# Q       : Which team held the scoring lead throughout the entire game?
# GT      : ['Broncos', 'The Broncos', 'Broncos']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beab833aeaaa14008c91d2
# Q       : Which Denver linebacker was named Super Bowl MVP?
# GT      : ['linebacker Von Miller', 'Von Miller', 'Miller']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beab833aeaaa14008c91d3
# Q       : How many solo tackles did Von Miller make at Super Bowl 50?
# GT      : ['five solo tackles', 'five', 'five']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beab833aeaaa14008c91d4
# Q       : Who was limited by Denver's defense?
# GT      : ["Newton was limited by Denver's defense", 'Newton', 'Newton']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beae423aeaaa14008c91f4
# Q       : How many times was Cam Newton sacked?
# GT      : ['seven', 'seven', 'seven']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beae423aeaaa14008c91f5
# Q       : Who won the Super Bowl MVP?
# GT      : ['Von Miller', 'The Broncos', 'Miller']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beae423aeaaa14008c91f6
# Q       : How many turnovers did Cam Newton have?
# GT      : ['three', 'three', 'three']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beae423aeaaa14008c91f7
# Q       : How many fumbles did Von Miller force?
# GT      : ['two', 'two', 'two']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf17653aeaaa14008c9511
# Q       : Who was given the esteemed status of MVP for Super Bowl 50?
# GT      : ['Von Miller', 'Von Miller', 'Miller']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf17653aeaaa14008c9513
# Q       : What position does Von Miller play for the Denver Broncos?
# GT      : ['linebacker', 'linebacker', 'linebacker']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf17653aeaaa14008c9514
# Q       : What was the number of solo tackles that Von Miller had in Super Bowl 50?
# GT      : ['5', 'five', 'five']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf17653aeaaa14008c9515
# Q       : How many forced fumbles did Von Miller have during the Super Bowl 50 game?
# GT      : ['2', 'two', 'two']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d204ade7d4791d00902603
# Q       : Who won the MVP for the Super Bowl?
# GT      : ['Von Miller', 'Von Miller', 'Von Miller']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d204ade7d4791d00902604
# Q       : How many tackles did Von Miller get during the game?
# GT      : ['5', 'five', 'five']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d601e41c85041400946ece
# Q       : How many times was Cam Newton sacked in Super Bowl 50?
# GT      : ['seven', 'seven', 'seven']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d601e41c85041400946ecf
# Q       : How many times did the Denver defense force Newton into turnovers?
# GT      : ['three', 'three', 'three']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d601e41c85041400946ed0
# Q       : Which Newton turnover resulted in seven points for Denver?
# GT      : ['a fumble', 'a fumble', 'fumble']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d601e41c85041400946ed1
# Q       : Who was the Most Valuable Player of Super Bowl 50?
# GT      : ['Von Miller', 'Von Miller', 'Von Miller']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d601e41c85041400946ed2
# Q       : What position does Von Miller play?
# GT      : ['linebacker', 'linebacker', 'linebacker']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d98b33dc89441400fdb53b
# Q       : How many times was the Panthers' quarterback sacked?
# GT      : ['seven', 'seven', 'seven']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d98b33dc89441400fdb53c
# Q       : How many times did the Broncos cause turnovers in the game?
# GT      : ['three', 'three', 'three']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d98b33dc89441400fdb53d
# Q       : What Denver player caused two fumbles for the Panthers?
# GT      : ['Von Miller', 'Von Miller', 'Von Miller']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d98b33dc89441400fdb53e
# Q       : How many tackles did Von Miller accomlish by himself in the game?
# GT      : ['five', 'five', 'five']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be5333acb8001400a5030a
# Q       : Which network broadcasted Super Bowl 50 in the U.S.?
# GT      : ['CBS', 'CBS', 'CBS']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be5333acb8001400a5030b
# Q       : What was the average cost for a 30 second commercial during Super Bowl 50?
# GT      : ['$5 million', '$5 million', '$5 million']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be5333acb8001400a5030c
# Q       : Which group headlined the Super Bowl 50 halftime show?
# GT      : ['Coldplay', 'Coldplay', 'Coldplay']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be5333acb8001400a5030d
# Q       : Which performers joined the headliner during the Super Bowl 50 halftime show?
# GT      : ['Beyoncé and Bruno Mars', 'Beyoncé and Bruno Mars', 'Beyoncé and Bruno Mars']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56be5333acb8001400a5030e
# Q       : At which Super Bowl did Beyonce headline the halftime show?
# GT      : ['Super Bowl XLVII', 'Super Bowl XLVII', 'XLVII']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beaf5e3aeaaa14008c91fd
# Q       : Who was the broadcaster for Super Bowl 50 in the United States?
# GT      : ['CBS', 'CBS', 'CBS']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beaf5e3aeaaa14008c91fe
# Q       : What was the average cost of a 30-second commercial?
# GT      : ['$5 million', '$5 million', '$5 million']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beaf5e3aeaaa14008c91ff
# Q       : What halftime performer previously headlined Super Bowl XLVII?
# GT      : ['Beyoncé', 'Beyoncé', 'Beyoncé']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beaf5e3aeaaa14008c9200
# Q       : What halftime performer previously headlined Super Bowl XLVIII?
# GT      : ['Bruno Mars', 'Bruno Mars', 'Mars']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56beaf5e3aeaaa14008c9201
# Q       : Who was the main performer at this year's halftime show?
# GT      : ['Coldplay', 'Coldplay', 'Coldplay']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf1ae93aeaaa14008c951b
# Q       : Which network broadcasted the 50th Super Bowl game?
# GT      : ['CBS', 'CBS', 'CBS']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf1ae93aeaaa14008c951c
# Q       : What was the average cost for a TV ad lasting 30 seconds during Super Bowl 50?
# GT      : ['$5 million', '$5 million', '$5 million']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf1ae93aeaaa14008c951e
# Q       : Who was the male singer who performed as a special guest during Super Bowl 50?
# GT      : ['Bruno Mars', 'Bruno Mars', 'Bruno Mars,']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56bf1ae93aeaaa14008c951f
# Q       : What ranking does the Super Bowl 50 halftime show have on the list of most watched TV broadcasts?
# GT      : ['third', 'third', 'third']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d2051ce7d4791d00902608
# Q       : What station aired the Super Bowl?
# GT      : ['CBS', 'CBS', 'CBS']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d2051ce7d4791d00902609
# Q       : How much money did a 1/2 minute commercial cost?
# GT      : ['$5 million', '$5 million', '$5 million']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d2051ce7d4791d0090260a
# Q       : What band headlined half-time during Super Bowl 50?
# GT      : ['Coldplay', 'Coldplay', 'Coldplay']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d2051ce7d4791d0090260b
# Q       : What two artists came out with Coldplay during the half-time show?
# GT      : ['Beyoncé and Bruno Mars', 'Beyoncé and Bruno Mars', 'Beyoncé and Bruno Mars']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d602631c85041400946ed8
# Q       : Who broadcast the Super Bowl on TV?
# GT      : ['CBS', 'CBS', 'CBS']
# PRED    : ''
# ==== DEBUG EXAMPLE ====
# ID      : 56d602631c85041400946eda
# Q       : Who headlined the halftime show for Super Bowl 50?
# GT      : ['Coldplay', 'Coldplay', 'Coldplay']
# PRED    : ''
# INFO - Evaluation completed successfully
# INFO - Metrics summary: {'squadv1': {'alias': 'squadv1', 'exact,none': 0.0, 'exact_stderr,none': 'N/A', 'f1,none': 0.0, 'f1_stderr,none': 'N/A'}}
# INFO - Saved results to: /content/drive/MyDrive/TUM/Pratikum/SliceGPTExperiments/eval/squad_dense_only/results_s0.00_squadv1_squadv1.json
# INFO - Finished SQuADv1 evaluation script

# %%
import os
import json
import torch
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
import evaluate
from tqdm import tqdm

# ----------------------------
# 1. Config
# ----------------------------
MODEL_NAME = "facebook/opt-1.3b"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
MAX_NEW_TOKENS = 32
LIMIT = 100  # number of validation examples

SAVE_DIR = "/content/drive/MyDrive/TUM/Pratikum/SliceGPTExperiments/eval/squad_dense_only/"
os.makedirs(SAVE_DIR, exist_ok=True)
OUT_PATH = os.path.join(SAVE_DIR, "results_s0.00_squadv1_manual.json")

print("Device:", DEVICE)

# ----------------------------
# 2. Load model & tokenizer
# ----------------------------
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME).to(DEVICE)
model.eval()

# OPT often has no pad token, so use eos as pad
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id

# ----------------------------
# 3. Load SQuAD1.1 validation
# ----------------------------
dataset = load_dataset("squad", split="validation")
if LIMIT is not None:
    dataset = dataset.select(range(LIMIT))

print("Evaluating on", len(dataset), "examples")

# ----------------------------
# 4. Run generation
# ----------------------------
predictions = []
references = []

for doc in tqdm(dataset):
    prompt = (
        "Context: " + doc["context"]
        + "\nQuestion: " + doc["question"]
        + "\nAnswer:"
    )

    enc = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=1024,
    ).to(DEVICE)

    with torch.no_grad():
        out = model.generate(
            **enc,
            max_new_tokens=MAX_NEW_TOKENS,
            do_sample=False,
            temperature=0.0,
            pad_token_id=tokenizer.eos_token_id,
        )

    # Decode only the newly generated tokens
    generated = out[0, enc["input_ids"].shape[1]:]
    text = tokenizer.decode(generated, skip_special_tokens=True).strip()

    # DEBUG: print first few
    if len(predictions) < 5:
        print("==== DEBUG EXAMPLE ====")
        print("Q   :", doc["question"])
        print("GT  :", doc["answers"]["text"])
        print("PRED:", repr(text))

    predictions.append({
        "id": doc["id"],
        "prediction_text": text,
    })
    references.append({
        "id": doc["id"],
        "answers": doc["answers"],
    })

# ----------------------------
# 5. Compute SQuAD1 metrics
# ----------------------------
metric = evaluate.load("squad")  # SQuAD 1.1 EM/F1
scores = metric.compute(predictions=predictions, references=references)
print("Scores:", scores)

# ----------------------------
# 6. Save results
# ----------------------------
with open(OUT_PATH, "w") as f:
    json.dump({
        "results": scores,
        "num_examples": len(dataset),
        "model": MODEL_NAME,
    }, f, indent=2)

print("Saved to:", OUT_PATH)
# Out:
# Device: cuda
# tokenizer_config.json:   0%|          | 0.00/685 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/653 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/441 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.63G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]
# Evaluating on 100 examples
#   0%|          | 0/100 [00:00<?, ?it/s]
#   1%|          | 1/100 [00:00<01:10,  1.41it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Which NFL team represented the AFC at Super Bowl 50?
# GT  : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED: 'The Denver Broncos.\n\nThe Denver Broncos are an American football team based in Denver, Colorado. They are members of the National Football League (NFL), a'
#   2%|▏         | 2/100 [00:01<01:00,  1.61it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Which NFL team represented the NFC at Super Bowl 50?
# GT  : ['Carolina Panthers', 'Carolina Panthers', 'Carolina Panthers']
# PRED: 'The Carolina Panthers.\n\nThe Carolina Panthers are an American football team based in Charlotte, North Carolina. They are members of the National Football League (NFL),'
#   3%|▎         | 3/100 [00:01<00:56,  1.71it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Where did Super Bowl 50 take place?
# GT  : ['Santa Clara, California', "Levi's Stadium", "Levi's Stadium in the San Francisco Bay Area at Santa Clara, California."]
# PRED: "Super Bowl 50 took place at Levi's Stadium in Santa Clara, California, on February 7, 2016.\nThe stadium is located in the city of Santa Clara"
#   4%|▍         | 4/100 [00:02<00:54,  1.76it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Which NFL team won Super Bowl 50?
# GT  : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED: 'The Denver Broncos.\nThe Denver Broncos defeated the Carolina Panthers 24–10 in Super Bowl 50.\nThe Denver Broncos defeated the Carolina Panthers 24–10 in'
#   5%|▌         | 5/100 [00:02<00:49,  1.92it/s]
# ==== DEBUG EXAMPLE ====
# Q   : What color was used to emphasize the 50th anniversary of the Super Bowl?
# GT  : ['gold', 'gold', 'gold']
# PRED: 'The color of the 50th Super Bowl logo was gold.\n\nReferences\n\nExternal links\n\nSuper Bowl 50'
#   6%|▌         | 6/100 [00:03<00:49,  1.90it/s]
#   7%|▋         | 7/100 [00:03<00:49,  1.90it/s]
#   8%|▊         | 8/100 [00:04<00:48,  1.89it/s]
#   9%|▉         | 9/100 [00:04<00:48,  1.89it/s]
#  10%|█         | 10/100 [00:05<00:47,  1.90it/s]
#  11%|█         | 11/100 [00:05<00:46,  1.90it/s]
#  12%|█▏        | 12/100 [00:06<00:47,  1.87it/s]
#  13%|█▎        | 13/100 [00:07<00:46,  1.88it/s]
#  14%|█▍        | 14/100 [00:07<00:45,  1.89it/s]
#  15%|█▌        | 15/100 [00:07<00:42,  2.01it/s]
#  16%|█▌        | 16/100 [00:08<00:42,  1.98it/s]
#  17%|█▋        | 17/100 [00:09<00:42,  1.96it/s]
#  18%|█▊        | 18/100 [00:09<00:42,  1.95it/s]
#  19%|█▉        | 19/100 [00:10<00:41,  1.94it/s]
#  20%|██        | 20/100 [00:10<00:41,  1.94it/s]
#  21%|██        | 21/100 [00:10<00:34,  2.28it/s]
#  22%|██▏       | 22/100 [00:11<00:36,  2.16it/s]
#  23%|██▎       | 23/100 [00:11<00:37,  2.08it/s]
#  24%|██▍       | 24/100 [00:12<00:37,  2.03it/s]
#  25%|██▌       | 25/100 [00:12<00:37,  1.99it/s]
#  26%|██▌       | 26/100 [00:13<00:37,  1.97it/s]
#  27%|██▋       | 27/100 [00:13<00:37,  1.97it/s]
#  28%|██▊       | 28/100 [00:14<00:36,  1.95it/s]
#  29%|██▉       | 29/100 [00:15<00:37,  1.92it/s]
#  30%|███       | 30/100 [00:15<00:36,  1.90it/s]
#  31%|███       | 31/100 [00:16<00:36,  1.90it/s]
#  32%|███▏      | 32/100 [00:16<00:35,  1.89it/s]
#  33%|███▎      | 33/100 [00:17<00:35,  1.90it/s]
#  34%|███▍      | 34/100 [00:17<00:34,  1.91it/s]
#  35%|███▌      | 35/100 [00:18<00:33,  1.92it/s]
#  36%|███▌      | 36/100 [00:18<00:33,  1.92it/s]
#  37%|███▋      | 37/100 [00:19<00:32,  1.92it/s]
#  38%|███▊      | 38/100 [00:19<00:32,  1.92it/s]
#  39%|███▉      | 39/100 [00:20<00:31,  1.93it/s]
#  40%|████      | 40/100 [00:20<00:31,  1.93it/s]
#  41%|████      | 41/100 [00:21<00:30,  1.93it/s]
#  42%|████▏     | 42/100 [00:21<00:30,  1.93it/s]
#  43%|████▎     | 43/100 [00:22<00:29,  1.91it/s]
#  44%|████▍     | 44/100 [00:22<00:29,  1.92it/s]
#  45%|████▌     | 45/100 [00:23<00:28,  1.93it/s]
#  46%|████▌     | 46/100 [00:23<00:27,  1.93it/s]
#  47%|████▋     | 47/100 [00:24<00:27,  1.93it/s]
#  48%|████▊     | 48/100 [00:24<00:26,  1.94it/s]
#  49%|████▉     | 49/100 [00:25<00:26,  1.94it/s]
#  50%|█████     | 50/100 [00:25<00:25,  1.94it/s]
#  51%|█████     | 51/100 [00:26<00:25,  1.94it/s]
#  52%|█████▏    | 52/100 [00:26<00:24,  1.93it/s]
#  53%|█████▎    | 53/100 [00:27<00:24,  1.91it/s]
#  54%|█████▍    | 54/100 [00:28<00:24,  1.90it/s]
#  55%|█████▌    | 55/100 [00:28<00:23,  1.91it/s]
#  56%|█████▌    | 56/100 [00:29<00:22,  1.92it/s]
#  57%|█████▋    | 57/100 [00:29<00:22,  1.92it/s]
#  58%|█████▊    | 58/100 [00:30<00:21,  1.93it/s]
#  59%|█████▉    | 59/100 [00:30<00:21,  1.94it/s]
#  60%|██████    | 60/100 [00:31<00:20,  1.95it/s]
#  61%|██████    | 61/100 [00:31<00:19,  1.96it/s]
#  62%|██████▏   | 62/100 [00:32<00:19,  1.97it/s]
#  63%|██████▎   | 63/100 [00:32<00:18,  1.97it/s]
#  64%|██████▍   | 64/100 [00:33<00:18,  1.97it/s]
#  65%|██████▌   | 65/100 [00:33<00:17,  1.97it/s]
#  66%|██████▌   | 66/100 [00:34<00:17,  1.97it/s]
#  67%|██████▋   | 67/100 [00:34<00:16,  1.97it/s]
#  68%|██████▊   | 68/100 [00:35<00:16,  1.97it/s]
#  69%|██████▉   | 69/100 [00:35<00:15,  1.97it/s]
#  70%|███████   | 70/100 [00:36<00:15,  1.97it/s]
#  71%|███████   | 71/100 [00:36<00:14,  1.98it/s]
#  72%|███████▏  | 72/100 [00:37<00:14,  1.97it/s]
#  73%|███████▎  | 73/100 [00:37<00:13,  1.97it/s]
#  74%|███████▍  | 74/100 [00:38<00:13,  1.97it/s]
#  75%|███████▌  | 75/100 [00:38<00:12,  1.97it/s]
#  76%|███████▌  | 76/100 [00:39<00:12,  1.97it/s]
#  77%|███████▋  | 77/100 [00:39<00:11,  1.94it/s]
#  78%|███████▊  | 78/100 [00:40<00:11,  1.94it/s]
#  79%|███████▉  | 79/100 [00:40<00:10,  1.94it/s]
#  80%|████████  | 80/100 [00:41<00:10,  1.94it/s]
#  81%|████████  | 81/100 [00:41<00:09,  1.94it/s]
#  82%|████████▏ | 82/100 [00:42<00:09,  1.94it/s]
#  83%|████████▎ | 83/100 [00:42<00:08,  1.94it/s]
#  84%|████████▍ | 84/100 [00:43<00:08,  1.95it/s]
#  85%|████████▌ | 85/100 [00:43<00:07,  1.95it/s]
#  86%|████████▌ | 86/100 [00:44<00:07,  1.95it/s]
#  87%|████████▋ | 87/100 [00:44<00:06,  1.95it/s]
#  88%|████████▊ | 88/100 [00:45<00:06,  1.95it/s]
#  89%|████████▉ | 89/100 [00:45<00:05,  1.95it/s]
#  90%|█████████ | 90/100 [00:46<00:05,  1.95it/s]
#  91%|█████████ | 91/100 [00:46<00:04,  1.95it/s]
#  92%|█████████▏| 92/100 [00:47<00:04,  1.96it/s]
#  93%|█████████▎| 93/100 [00:47<00:03,  1.96it/s]
#  94%|█████████▍| 94/100 [00:48<00:03,  1.96it/s]
#  95%|█████████▌| 95/100 [00:49<00:02,  1.96it/s]
#  96%|█████████▌| 96/100 [00:49<00:02,  1.95it/s]
#  97%|█████████▋| 97/100 [00:50<00:01,  1.95it/s]
#  98%|█████████▊| 98/100 [00:50<00:01,  1.95it/s]
#  99%|█████████▉| 99/100 [00:51<00:00,  1.95it/s]
# 100%|██████████| 100/100 [00:51<00:00,  1.94it/s]
# Scores: {'exact_match': 0.0, 'f1': 13.358174968017229}
# Saved to: /content/drive/MyDrive/TUM/Pratikum/SliceGPTExperiments/eval/squad_dense_only/results_s0.00_squadv1_manual.json

# %%
#we put a max_tokens smaller in order to have more exact match
import os
import json
import torch
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
import evaluate
from tqdm import tqdm

# ----------------------------
# 1. Config
# ----------------------------
MODEL_NAME = "facebook/opt-1.3b"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
MAX_NEW_TOKENS = 8
LIMIT = 100  # number of validation examples

SAVE_DIR = "/content/drive/MyDrive/TUM/Pratikum/SliceGPTExperiments/eval/squad_dense_only/"
os.makedirs(SAVE_DIR, exist_ok=True)
OUT_PATH = os.path.join(SAVE_DIR, "results_s0.00_squadv1_manual.json")

print("Device:", DEVICE)

# ----------------------------
# 2. Load model & tokenizer
# ----------------------------
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME).to(DEVICE)
model.eval()

# OPT often has no pad token, so use eos as pad
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id

# ----------------------------
# 3. Load SQuAD1.1 validation
# ----------------------------
dataset = load_dataset("squad", split="validation")
if LIMIT is not None:
    dataset = dataset.select(range(LIMIT))

print("Evaluating on", len(dataset), "examples")

# ----------------------------
# 4. Run generation
# ----------------------------
predictions = []
references = []

for doc in tqdm(dataset):
    prompt = (
        "Context: " + doc["context"]
        + "\nQuestion: " + doc["question"]
        + "\nAnswer:"
    )

    enc = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=1024,
    ).to(DEVICE)

    with torch.no_grad():
        out = model.generate(
            **enc,
            max_new_tokens=MAX_NEW_TOKENS,
            do_sample=False,
            temperature=0.0,
            pad_token_id=tokenizer.eos_token_id,
        )

    # Decode only the newly generated tokens
    generated = out[0, enc["input_ids"].shape[1]:]
    text = tokenizer.decode(generated, skip_special_tokens=True).strip()

    # DEBUG: print first few
    if len(predictions) < 5:
        print("==== DEBUG EXAMPLE ====")
        print("Q   :", doc["question"])
        print("GT  :", doc["answers"]["text"])
        print("PRED:", repr(text))

    predictions.append({
        "id": doc["id"],
        "prediction_text": text,
    })
    references.append({
        "id": doc["id"],
        "answers": doc["answers"],
    })

# ----------------------------
# 5. Compute SQuAD1 metrics
# ----------------------------
metric = evaluate.load("squad")  # SQuAD 1.1 EM/F1
scores = metric.compute(predictions=predictions, references=references)
print("Scores:", scores)

# ----------------------------
# 6. Save results
# ----------------------------
with open(OUT_PATH, "w") as f:
    json.dump({
        "results": scores,
        "num_examples": len(dataset),
        "model": MODEL_NAME,
    }, f, indent=2)

print("Saved to:", OUT_PATH)
# Out:
# Device: cuda
# Evaluating on 100 examples
#   1%|          | 1/100 [00:00<00:15,  6.20it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Which NFL team represented the AFC at Super Bowl 50?
# GT  : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED: 'The Denver Broncos.\n\nThe Denver'
#   2%|▏         | 2/100 [00:00<00:15,  6.32it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Which NFL team represented the NFC at Super Bowl 50?
# GT  : ['Carolina Panthers', 'Carolina Panthers', 'Carolina Panthers']
# PRED: 'The Carolina Panthers.\n\nThe Carolina'
#   3%|▎         | 3/100 [00:00<00:15,  6.36it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Where did Super Bowl 50 take place?
# GT  : ['Santa Clara, California', "Levi's Stadium", "Levi's Stadium in the San Francisco Bay Area at Santa Clara, California."]
# PRED: "Super Bowl 50 took place at Levi's"
#   4%|▍         | 4/100 [00:00<00:14,  6.45it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Which NFL team won Super Bowl 50?
# GT  : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED: 'The Denver Broncos.\nThe Denver Broncos'
#   5%|▌         | 5/100 [00:00<00:14,  6.48it/s]
# ==== DEBUG EXAMPLE ====
# Q   : What color was used to emphasize the 50th anniversary of the Super Bowl?
# GT  : ['gold', 'gold', 'gold']
# PRED: 'The color of the 50th Super Bowl'
# 100%|██████████| 100/100 [00:14<00:00,  6.82it/s]
# Scores: {'exact_match': 2.0, 'f1': 36.4576479076479}
# Saved to: /content/drive/MyDrive/TUM/Pratikum/SliceGPTExperiments/eval/squad_dense_only/results_s0.00_squadv1_manual.json

# %%
#different prompt to get smaller answers
#we put a max_tokens smaller in order to have more exact match
import os
import json
import torch
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForCausalLM
import evaluate
from tqdm import tqdm

# ----------------------------
# 1. Config
# ----------------------------
MODEL_NAME = "facebook/opt-1.3b"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
MAX_NEW_TOKENS = 8
LIMIT = 100  # number of validation examples

SAVE_DIR = "/content/drive/MyDrive/TUM/Pratikum/SliceGPTExperiments/eval/squad_dense_only/"
os.makedirs(SAVE_DIR, exist_ok=True)
OUT_PATH = os.path.join(SAVE_DIR, "results_s0.00_squadv1_manual.json")

print("Device:", DEVICE)

# ----------------------------
# 2. Load model & tokenizer
# ----------------------------
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
model = AutoModelForCausalLM.from_pretrained(MODEL_NAME).to(DEVICE)
model.eval()

# OPT often has no pad token, so use eos as pad
if tokenizer.pad_token_id is None:
    tokenizer.pad_token_id = tokenizer.eos_token_id

# ----------------------------
# 3. Load SQuAD1.1 validation
# ----------------------------
dataset = load_dataset("squad", split="validation")
if LIMIT is not None:
    dataset = dataset.select(range(LIMIT))

print("Evaluating on", len(dataset), "examples")

# ----------------------------
# 4. Run generation
# ----------------------------
predictions = []
references = []

for doc in tqdm(dataset):
    prompt = (
        "Context: " + doc["context"]
        + "\nQuestion: " + doc["question"]
        + "\nAnswer with a short phrase (no explanation):"
    )

    enc = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=1024,
    ).to(DEVICE)

    with torch.no_grad():
        out = model.generate(
            **enc,
            max_new_tokens=MAX_NEW_TOKENS,
            do_sample=False,
            temperature=0.0,
            pad_token_id=tokenizer.eos_token_id,
        )

    # Decode only the newly generated tokens
    generated = out[0, enc["input_ids"].shape[1]:]
    text = tokenizer.decode(generated, skip_special_tokens=True).strip()

    # DEBUG: print first few
    if len(predictions) < 5:
        print("==== DEBUG EXAMPLE ====")
        print("Q   :", doc["question"])
        print("GT  :", doc["answers"]["text"])
        print("PRED:", repr(text))

    predictions.append({
        "id": doc["id"],
        "prediction_text": text,
    })
    references.append({
        "id": doc["id"],
        "answers": doc["answers"],
    })

# ----------------------------
# 5. Compute SQuAD1 metrics
# ----------------------------
metric = evaluate.load("squad")  # SQuAD 1.1 EM/F1
scores = metric.compute(predictions=predictions, references=references)
print("Scores:", scores)

# ----------------------------
# 6. Save results
# ----------------------------
with open(OUT_PATH, "w") as f:
    json.dump({
        "results": scores,
        "num_examples": len(dataset),
        "model": MODEL_NAME,
    }, f, indent=2)

print("Saved to:", OUT_PATH)
# Out:
# Device: cuda
# Evaluating on 100 examples
#   1%|          | 1/100 [00:00<00:16,  6.17it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Which NFL team represented the AFC at Super Bowl 50?
# GT  : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED: 'The answer is:'
#   2%|▏         | 2/100 [00:00<00:15,  6.25it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Which NFL team represented the NFC at Super Bowl 50?
# GT  : ['Carolina Panthers', 'Carolina Panthers', 'Carolina Panthers']
# PRED: 'The answer is:'
#   3%|▎         | 3/100 [00:00<00:15,  6.45it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Where did Super Bowl 50 take place?
# GT  : ['Santa Clara, California', "Levi's Stadium", "Levi's Stadium in the San Francisco Bay Area at Santa Clara, California."]
# PRED: 'The Super Bowl is a football'
#   4%|▍         | 4/100 [00:00<00:14,  6.55it/s]
# ==== DEBUG EXAMPLE ====
# Q   : Which NFL team won Super Bowl 50?
# GT  : ['Denver Broncos', 'Denver Broncos', 'Denver Broncos']
# PRED: 'The answer is:'
#   5%|▌         | 5/100 [00:00<00:14,  6.59it/s]
# ==== DEBUG EXAMPLE ====
# Q   : What color was used to emphasize the 50th anniversary of the Super Bowl?
# GT  : ['gold', 'gold', 'gold']
# PRED: 'The color of the 50th'
# 100%|██████████| 100/100 [00:14<00:00,  6.82it/s]
# Scores: {'exact_match': 0.0, 'f1': 18.63181818181818}
# Saved to: /content/drive/MyDrive/TUM/Pratikum/SliceGPTExperiments/eval/squad_dense_only/results_s0.00_squadv1_manual.json
